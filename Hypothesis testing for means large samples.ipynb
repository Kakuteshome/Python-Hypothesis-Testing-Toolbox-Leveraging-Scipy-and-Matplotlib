# %%
from scipy import stats
import matplotlib.pyplot as plt
import numpy as np

# %%
def calculate_z_score(sample_mean, population_mean, standard_deviation, sample_size):
    """Calculate the z-score for hypothesis testing."""
    return (sample_mean - population_mean) / (standard_deviation / (sample_size ** 0.5))

def perform_hypothesis_test(z_score, alpha,tail):
    """Perform the hypothesis test and plot the normal distribution."""
    # Calculate critical value (one-tailed test)
    if tail.lower() == 'upper':
        critical_value = stats.norm.ppf(1 - alpha)
    elif tail.lower() == 'lower':
        critical_value = stats.norm.ppf(alpha)

    # Print the z-score and critical value
    print("Z-score:", z_score)
    print("Critical Value:", critical_value)

    # Perform hypothesis test
    if np.abs(z_score) > np.abs(critical_value):
        print("Reject Null Hypothesis (H0)")
    else:
        print("Fail to Reject Null Hypothesis (H0)")

    # Plot the normal distribution
    x = np.linspace(-3, 3, 100)
    y = stats.norm.pdf(x, 0, 1)
    plt.plot(x, y)
    if tail.lower() == 'upper':
        plt.fill_between(x[x > critical_value], 0, stats.norm.pdf(x[x > critical_value], 0, 1), color='red', alpha=0.5)
    elif tail.lower() == 'lower':
        plt.fill_between(x[x < critical_value], 0, stats.norm.pdf(x[x < critical_value], 0, 1), color='red', alpha=0.5)
    plt.axvline(x=critical_value,linestyle='--',color='black')
    plt.axvline(x=z_score,linestyle='--',color='green')
    plt.text(critical_value + 0.1, 0.1, 'Critical Region', fontsize=10, color='red')
    plt.xlabel('Z-score')
    plt.ylabel('Probability Density')
    plt.title('Normal Distribution with Critical Region')
    plt.show()

# %%
def plot_two_tailed_hypothesis_test(alpha,z):
    # Generate x values for the plot
    x = np.linspace(-4, 4, 1000)

    # Calculate the critical values for a two-tailed test
    critical_value_left = stats.norm.ppf(alpha / 2)
    critical_value_right = stats.norm.ppf(1 - alpha / 2)

    # Plot the standard normal distribution
    plt.plot(x, stats.norm.pdf(x, 0, 1), label='Standard Normal Distribution')

    # Shade the left critical region
    plt.fill_between(x[x < critical_value_left], 0, stats.norm.pdf(x[x < critical_value_left], 0, 1), color='red', alpha=0.5)

    # Shade the right critical region
    plt.fill_between(x[x > critical_value_right], 0, stats.norm.pdf(x[x > critical_value_right], 0, 1), color='red', alpha=0.5)

    # Plot vertical lines at the critical values
    plt.axvline(critical_value_left, color='red', linestyle='--', label='Critical Values')
    plt.axvline(critical_value_right, color='red', linestyle='--')
    plt.axvline(z, color='green', linestyle='--')


    # Add labels and legend
    plt.xlabel('x')
    plt.ylabel('Probability Density')
    plt.title('Two-Tailed Hypothesis Test')
    plt.legend()

    # Show plot
    plt.show()

# %% [markdown]
# #Q5

# %%
# Given data
sample_mean = 21
population_mean = 20  # Null hypothesis value
standard_deviation = 5
sample_size = 36
alpha = 0.05

# Calculate z-score
z_score = calculate_z_score(sample_mean, population_mean, standard_deviation, sample_size)

# Perform hypothesis test and plot normal distribution
perform_hypothesis_test(z_score, alpha,'upper')
# Out:
# Z-score: 1.2
# Critical Value: 1.6448536269514722
# Fail to Reject Null Hypothesis (H0): The population mean is not greater than 20

# %% [markdown]
# #Q6

# %%
# Given data
sample_mean = 215
population_mean = 220  # Null hypothesis value
standard_deviation = 15
sample_size = 64
alpha = 0.03

# Calculate z-score
z_score = calculate_z_score(sample_mean, population_mean, standard_deviation, sample_size)

# Perform hypothesis test and plot normal distribution
perform_hypothesis_test(z_score, alpha,'lower')
# Out:
# Z-score: -2.6666666666666665
# Critical Value: -1.880793608151251
# Reject Null Hypothesis (H0): The population mean is greater than 220

# %% [markdown]
# #Q7

# %%
# Given data
sample_mean = 6.2
population_mean = 6.8  # Null hypothesis value
standard_deviation = 0.5
sample_size = 36
alpha = 0.05

# Calculate z-score
z_score = calculate_z_score(sample_mean, population_mean, standard_deviation, sample_size)

# Perform hypothesis test and plot normal distribution
perform_hypothesis_test(z_score, alpha,'lower')
# Out:
# Z-score: -7.199999999999996
# Critical Value: -1.6448536269514729
# Reject Null Hypothesis (H0): The population mean is greater than 6.8

# %% [markdown]
# #Q8

# %%
# Given data
sample_mean = 24.85
population_mean = 20  # Null hypothesis value
standard_deviation = 3.24
sample_size = 35
alpha = 0.01

# Calculate z-score
z_score = calculate_z_score(sample_mean, population_mean, standard_deviation, sample_size)

# Perform hypothesis test and plot normal distribution
perform_hypothesis_test(z_score, alpha,'upper')
# Out:
# Z-score: 8.855860169146032
# Critical Value: 2.3263478740408408
# Reject Null Hypothesis (H0): The population mean is greater than 20

# %%
# Given data for two population means
sample1_mean = 16
sample2_mean = 15.2  
std1 = 1
std2 = 1.2
n1= 400
n2=100
alpha = 0.05

# Calculate z-score
z_score = (sample1_mean - sample2_mean)/((std1**2/n1)+(std2**2/n2))**0.5

# Perform hypothesis test and plot normal distribution
perform_hypothesis_test(z_score, alpha,'upper')
# Out:
# Z-score: 6.1538461538461595
# Critical Value: 1.6448536269514722
# Reject Null Hypothesis (H0)

# %% [markdown]
# #Q9

# %%
# Given data for two population means
sample1_mean = 102
sample2_mean = 99 
std1 = 5
std2 = 6
n1= 40
n2=50
alpha = 0.04

# Calculate z-score
z_score = (sample1_mean - sample2_mean)/((std1**2/n1)+(std2**2/n2))**0.5

# Perform hypothesis test and plot normal distribution
print(f'Z-score:{np.round(z_score,2)}')
plot_two_tailed_hypothesis_test(0.04,z_score)
# Out:
# Z-score:2.59

# %% [markdown]
# #Q10

# %%
# Given data for two population means
sample1_mean = 2.67
std1 = 0.75
n1= 65

sample2_mean = 2.59 
std2 = 0.66
n2=50
alpha = 0.08

# Calculate z-score
z_score = (sample1_mean - sample2_mean)/((std1**2/n1)+(std2**2/n2))**0.5

# Perform hypothesis test and plot normal distribution
#print(f'Z-score:{np.round(z_score,2)}')
perform_hypothesis_test(z_score,alpha=alpha,tail='upper')
# Out:
# Z-score: 0.6070745301096202
# Critical Value: 1.4050715603096329
# Fail to Reject Null Hypothesis (H0)

# %% [markdown]
# #Q11

# %%
# Given data for two population means
sample1_mean = 7.6
std1 = 2.3
n1= 40

sample2_mean = 8.1
std2 = 2.9
n2=55

alpha = 0.05

# Calculate z-score
z_score = (sample1_mean - sample2_mean)/((std1**2/n1)+(std2**2/n2))**0.5

# Perform hypothesis test and plot normal distribution
perform_hypothesis_test(z_score,alpha=alpha,tail='lower')
# Out:
# Z-score: -0.9363245134485892
# Critical Value: -1.6448536269514729
# Fail to Reject Null Hypothesis (H0)

# %% [markdown]
# #Q12

# %%
# Given data for two population means
sample1_mean = 370
std1 = 30
n1= 35

sample2_mean = 380
std2 = 26
n2=40

alpha = 0.05

# Calculate z-score
z_score = (sample1_mean - sample2_mean)/((std1**2/n1)+(std2**2/n2))**0.5

# Perform hypothesis test and plot normal distribution
print(f'Z-score:{np.round(z_score,2)}')
plot_two_tailed_hypothesis_test(0.04,z_score)
# Out:
# Z-score:-1.53

# %% [markdown]
# #Q13

# %%
# Out:
# -1.6448536269514729

# %%
# Given data for two population means
sample1_mean = 31.4
std1 = 5.1
n1= 32

sample2_mean = 34.9
std2 = 6.7
n2=40

alpha = 0.01

# Calculate z-score
z_score = (sample1_mean - sample2_mean)/((std1**2/n1)+(std2**2/n2))**0.5

# Perform hypothesis test and plot normal distribution
print(f'Z-score:{np.round(z_score,2)}')
plot_two_tailed_hypothesis_test(alpha,z_score)
# Out:
# Z-score:-2.52

# %% [markdown]
# #Q16

# %%
# Given data
sample_mean = 9
population_mean = 10  # Null hypothesis value
standard_deviation = 2.8
sample_size = 50
alpha = 0.05

# Calculate z-score
z_score = calculate_z_score(sample_mean, population_mean, standard_deviation, sample_size)

# Perform hypothesis test and plot normal distribution
perform_hypothesis_test(z_score, alpha,'lower')
print(f"p-value:{stats.norm.cdf(z_score,0,1)*100}%")
# Out:
# Z-score: -2.525381361380527
# Critical Value: -1.6448536269514729
# Reject Null Hypothesis (H0)
# p-value:0.5778639832162626%

# %% [markdown]
# #Q17

# %%
# Given data
sample_mean = 16.05
population_mean = 16  # Null hypothesis value
standard_deviation = 0.03
sample_size = 50
alpha = 0.05

# Calculate z-score
z_score = calculate_z_score(sample_mean, population_mean, standard_deviation, sample_size)

# Perform hypothesis test and plot normal distribution
perform_hypothesis_test(z_score, alpha,'upper')
print(f"p-value:{(1-stats.norm.cdf(z_score,0,1))*100}%")
# Out:
# Z-score: 11.78511301977596
# Critical Value: 1.6448536269514722
# Reject Null Hypothesis (H0)
# p-value:0.0%

# %% [markdown]
# #Q18

# %%
# Given data
sample_mean = 17000
population_mean = 15000  # Null hypothesis value
standard_deviation = 3000
sample_size = 75
alpha = 0.05

# Calculate z-score
z_score = calculate_z_score(sample_mean, population_mean, standard_deviation, sample_size)

# Perform hypothesis test and plot normal distribution
perform_hypothesis_test(z_score, alpha,'upper')
print(f"p-value:{(1-stats.norm.cdf(z_score,0,1))*100}%")
# Out:
# Z-score: 5.773502691896258
# Critical Value: 1.6448536269514722
# Reject Null Hypothesis (H0)
# p-value:3.882018262402198e-07%

# %% [markdown]
# #Q19

# %%
# Given data
sample_mean = 94
population_mean = 90  # Null hypothesis value
standard_deviation = 22
sample_size = 100
alpha = 0.1

# Calculate z-score
z_score = calculate_z_score(sample_mean, population_mean, standard_deviation, sample_size)

# Perform hypothesis test and plot normal distribution
perform_hypothesis_test(z_score, alpha,'upper')
print(f"p-value:{(1-stats.norm.cdf(z_score,0,1))*100}%")
# Out:
# Z-score: 1.8181818181818181
# Critical Value: 1.2815515655446004
# Reject Null Hypothesis (H0)
# p-value:3.451817399720758%

# %% [markdown]
# #Q20

# %%
n=120
sample_mean = 30500
population_mean = 30000
std = 3000
alpha=0.1

#Calculate the test score
z_score = (sample_mean - population_mean)/(std/n**0.5)

#calculate the critical values
cvs = stats.norm.ppf(alpha/2)
print('Critical values:',(-1*np.abs(cvs),np.abs(cvs)))

print(f'Z-score:{z_score}')
plot_two_tailed_hypothesis_test(alpha,z_score)
# Out:
# Critical values: (-1.6448536269514729, 1.6448536269514729)
# Z-score:1.8257418583505536

# %% [markdown]
# #Q21

# %%
# Given data
sample_mean = 26.9
population_mean = 28  # Null hypothesis value
standard_deviation = 8
sample_size = 127
alpha = 0.02

# Calculate z-score
z_score = calculate_z_score(sample_mean, population_mean, standard_deviation, sample_size)

# Perform hypothesis test and plot normal distribution
perform_hypothesis_test(z_score, alpha,'lower')
print(f"p-value:{(1-stats.norm.cdf(z_score,0,1))*100}%")
# Out:
# Z-score: -1.5495463045678906
# Critical Value: -2.053748910631823
# Fail to Reject Null Hypothesis (H0)
# p-value:93.93747753153797%

# %% [markdown]
# #Q22

# %%
# Given data for two population means
sample1_mean = 114.6
std1 = 9.1
n1= 40

sample2_mean = 117.9
std2 = 10.4
n2=50

alpha = 0.04

# Calculate z-score
z_score = (sample1_mean - sample2_mean)/((std1**2/n1)+(std2**2/n2))**0.5

# Perform hypothesis test and plot normal distribution
print(f'Z-score:{np.round(z_score,2)}')
plot_two_tailed_hypothesis_test(alpha,z_score)
print(f'p-value:{stats.norm.cdf(z_score)}')
# Out:
# Z-score:-1.6
# p-value:0.054372349396103546

# %% [markdown]
# #Q23

# %%
# Given data for two population means
sample1_mean = 20
std1 = 4
n1= 45

sample2_mean = 21
std2 = 3
n2=50

alpha = 0.05

# Calculate z-score
z_score = (sample1_mean - sample2_mean)/((std1**2/n1)+(std2**2/n2))**0.5

# Perform hypothesis test and plot normal distribution
print(f'Z-score:{np.round(z_score,2)}')
plot_two_tailed_hypothesis_test(alpha,z_score)
print(f'p-value:{stats.norm.cdf(z_score)}')
# Out:
# Z-score:-1.37
# p-value:0.08589691288596324

# %% [markdown]
# #Q24

# %%
# Given data for two population means
sample1_mean = 2175
std1 = 12
n1= 64

sample2_mean = 2050
std2 = 20
n2=36

alpha = 0.04

# Calculate z-score
z_score = (sample1_mean - sample2_mean)/((std1**2/n1)+(std2**2/n2))**0.5

# Perform hypothesis test and plot normal distribution
print(f'Z-score:{np.round(z_score,2)}')
plot_two_tailed_hypothesis_test(alpha,z_score)
print(f'p-value:{stats.norm.cdf(z_score)}')
# Out:
# Z-score:34.2
# p-value:1.0

# %% [markdown]
# #Q25

# %%
# Given data for two population means
sample1_mean = 31290
std1 = 1060
n1= 45

sample2_mean = 31330
std2 = 1900
n2= 60

alpha = 0.05

# Calculate z-score
z_score = (sample1_mean - sample2_mean)/((std1**2/n1)+(std2**2/n2))**0.5

# Perform hypothesis test and plot normal distribution
print(f'Z-score:{np.round(z_score,2)}')
perform_hypothesis_test(z_score,alpha,tail='lower')
print(f'p-value:{stats.norm.cdf(z_score)}')
# Out:
# Z-score:-0.14
# Z-score: -0.13708959838717535
# Critical Value: -1.75068607125217
# Fail to Reject Null Hypothesis (H0)
# p-value:0.4454799870642073

# %% [markdown]
# #Q26

# %%
# Given data
sample_mean = 1250
population_mean = 1010
standard_deviation = 205
sample_size = 400
alpha = 0.01

# Calculate z-score
z_score = calculate_z_score(sample_mean, population_mean, standard_deviation, sample_size)

# Perform hypothesis test and plot normal distribution
perform_hypothesis_test(z_score, alpha,'upper')
print(f"p-value:{(1-stats.norm.cdf(z_score,0,1))*100}%")
# Out:
# Z-score: 23.414634146341463
# Critical Value: 2.3263478740408408
# Reject Null Hypothesis (H0)
# p-value:0.0%

# %%
# Given data
sample_mean = 0.09
population_mean = 0.12  # Null hypothesis value
standard_deviation = 0.03
sample_size = 900
alpha = 0.05

# Calculate z-score
z_score = calculate_z_score(sample_mean, population_mean, standard_deviation, sample_size)

# Perform hypothesis test and plot normal distribution
perform_hypothesis_test(z_score, alpha,'lower')
print(f"p-value:{(stats.norm.cdf(z_score,0,1))*100}%")
# Out:
# Z-score: -30.0
# Critical Value: -1.6448536269514729
# Reject Null Hypothesis (H0)
# p-value:4.906713927147908e-196%

# %% [markdown]
# #Q28

# %%
# Given data
sample_mean = 190000
population_mean = 200000  # Null hypothesis value
standard_deviation = 12000
sample_size = 144
alpha = 0.05

# Calculate z-score
z_score = calculate_z_score(sample_mean, population_mean, standard_deviation, sample_size)

# Perform hypothesis test and plot normal distribution
perform_hypothesis_test(z_score, alpha,'lower')
print(f"p-value:{(stats.norm.cdf(z_score,0,1))*100}%")
# Out:
# Z-score: -10.0
# Critical Value: -1.6448536269514729
# Reject Null Hypothesis (H0)
# p-value:7.61985302416047e-22%

# %% [markdown]
# #Q29

# %%
# Given data
sample_mean = 3.69
population_mean = 3.65  # Null hypothesis value
standard_deviation = 0.24
sample_size = 45
alpha = 0.05

# Calculate z-score
z_score = calculate_z_score(sample_mean, population_mean, standard_deviation, sample_size)

# Perform hypothesis test and plot normal distribution
plot_two_tailed_hypothesis_test(alpha,z_score)

# %% [markdown]
# #Q30

# %%
# Given data for two population means
sample1_mean = 11
std1 = 2.65
n1= 36

sample2_mean = 8.9
std2 = 1.64
n2= 40

alpha = 0.01

# Calculate z-score
z_score = (sample1_mean - sample2_mean)/((std1**2/n1)+(std2**2/n2))**0.5

# Perform hypothesis test and plot normal distribution
print(f'Z-score:{np.round(z_score,2)}')
perform_hypothesis_test(z_score,alpha,tail='upper')
print(f'p-value:{1-stats.norm.cdf(z_score)}')
# Out:
# Z-score:4.1
# Z-score: 4.100268822291638
# Critical Value: 2.3263478740408408
# Reject Null Hypothesis (H0)
# p-value:2.0633524608348885e-05

# %% [markdown]
# #Q31

# %%
# Given data for two population means
sample1_mean = 345
std1 = 21
n1= 54

sample2_mean = 351
std2 = 28
n2= 60

alpha = 0.05

# Calculate z-score
z_score = (sample1_mean - sample2_mean)/((std1**2/n1)+(std2**2/n2))**0.5

# Perform hypothesis test and plot normal distribution
print(f'Z-score:{np.round(z_score,2)}')
perform_hypothesis_test(z_score,alpha,tail='lower')
print(f'p-value:{stats.norm.cdf(z_score)}')
# Out:
# Z-score:-1.3
# Z-score: -1.3020934719647141
# Critical Value: -1.6448536269514729
# Fail to Reject Null Hypothesis (H0)
# p-value:0.09644221724024343

# %% [markdown]
# #Q32

# %%
# Given data
sample_mean = 24421
population_mean = 25000  # Null hypothesis value
standard_deviation = 1944
sample_size = 35
alpha = 0.05

# Calculate z-score
z_score = calculate_z_score(sample_mean, population_mean, standard_deviation, sample_size)

# Perform hypothesis test and plot normal distribution
perform_hypothesis_test(z_score, alpha,'lower')
# Out:
# Z-score: -1.7620422810775092
# Critical Value: -1.6448536269514729
# Reject Null Hypothesis (H0)

# %% [markdown]
# #Q34

# %%
# Given data
sample_mean = 0.8
population_mean = 0.75  # Null hypothesis value
standard_deviation = 0.1
sample_size = 45
alpha = 0.05

# Calculate z-score
z_score = calculate_z_score(sample_mean, population_mean, standard_deviation, sample_size)

# Perform hypothesis test and plot normal distribution
perform_hypothesis_test(z_score, alpha,'upper')
# Out:
# Z-score: 3.354101966249688
# Critical Value: 1.6448536269514722
# Reject Null Hypothesis (H0)

# %% [markdown]
# #Q35

# %%
# Given data
sample_mean = 90
population_mean = 95  # Null hypothesis value
standard_deviation = 20
sample_size = 50
alpha = 0.05

# Calculate z-score
z_score = calculate_z_score(sample_mean, population_mean, standard_deviation, sample_size)

# Perform hypothesis test and plot normal distribution
perform_hypothesis_test(z_score, alpha,'lower')
# Out:
# Z-score: -1.7677669529663689
# Critical Value: -1.6448536269514729
# Reject Null Hypothesis (H0)

# %% [markdown]
# #Q36

# %%
# Given data for two population means
sample1_mean = 36.2
std1 = 1.14
n1= 35

sample2_mean = 37
std2 = 1.3
n2=40

alpha = 0.01

# Calculate z-score
z_score = (sample1_mean - sample2_mean)/((std1**2/n1)+(std2**2/n2))**0.5

# Perform hypothesis test and plot normal distribution
print(f'Z-score:{np.round(z_score,2)}')
plot_two_tailed_hypothesis_test(alpha,z_score)
print(f'p-value:{stats.norm.cdf(z_score)}')
# Out:
# Z-score:-2.84
# p-value:0.0022597398773715987
